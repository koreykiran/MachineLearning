# %% [markdown]
# # Classification (Workbook)
#
#
#
# <br/>
# <br/><br/><br/>
# ### ITCS6156/8156 Spring 2018
# ### Minwoo "Jake" Lee

# %%
import numpy as np
import matplotlib.pyplot as plt 
from mpl_toolkits.mplot3d import Axes3D
# %matplotlib inline
#%matplotlib notebook
import pandas as pd

# %% [markdown]
# ## Reading Breast Cancer from Scikit-Learn

# %%
from sklearn.datasets import load_breast_cancer

data = load_breast_cancer()

# %%
data.keys()
# Out:
# dict_keys(['data', 'target', 'target_names', 'DESCR', 'feature_names'])

# %%
data.feature_names
# Out:
# array(['mean radius', 'mean texture', 'mean perimeter', 'mean area',
#        'mean smoothness', 'mean compactness', 'mean concavity',
#        'mean concave points', 'mean symmetry', 'mean fractal dimension',
#        'radius error', 'texture error', 'perimeter error', 'area error',
#        'smoothness error', 'compactness error', 'concavity error',
#        'concave points error', 'symmetry error', 'fractal dimension error',
#        'worst radius', 'worst texture', 'worst perimeter', 'worst area',
#        'worst smoothness', 'worst compactness', 'worst concavity',
#        'worst concave points', 'worst symmetry', 'worst fractal dimension'],
#       dtype='<U23')

# %%
data.data.shape
# Out:
# (569, 30)

# %%
np.unique(data.target)
# Out:
# array([0, 1])

# %%
data.target_names
# Out:
# array(['malignant', 'benign'],
#       dtype='<U9')

# %% [markdown]
# #### Breast Cancer Dataset
#
# The data from Diagnostic Wisconsin Breast Cancer Database is duplicated in UCI repository http://archive.ics.uci.edu/ml/datasets/breast+cancer+wisconsin+%28diagnostic%29.
#
# Can you find the number of data samples that is classified as "malignant?"

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-37646d9aa3fd> in <module>()
# ----> 1 data.target_names.describe()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'describe'

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)
df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension           ...             worst radius  \
# ...

# %%
df.describe()
# Out:
#        mean radius  mean texture  mean perimeter    mean area  \
# count   569.000000    569.000000      569.000000   569.000000
# mean     14.127292     19.289649       91.969033   654.889104
# std       3.524049      4.301036       24.298981   351.914129
# min       6.981000      9.710000       43.790000   143.500000
# 25%      11.700000     16.170000       75.170000   420.300000
# 50%      13.370000     18.840000       86.240000   551.100000
# 75%      15.780000     21.800000      104.100000   782.700000
# max      28.110000     39.280000      188.500000  2501.000000
#
#        mean smoothness  mean compactness  mean concavity  mean concave points  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# std           0.014064          0.052813        0.079720             0.038803
# min           0.052630          0.019380        0.000000             0.000000
# ...

# %% [markdown]
# # Let us take a look at the data.
#
# The codes below is from https://www.kaggle.com/djokester/visualising-the-breast-cancer-wisconsin-data-set/code.
# Take a look at his example of visualizing the data in various ways.

# %%
# https://www.kaggle.com/djokester/visualising-the-breast-cancer-wisconsin-data-set/code

import seaborn as sns

features_mean = data.feature_names[:15]
plt.figure(figsize=(15,15))
heat = sns.heatmap(df[features_mean].corr(), vmax=1, square=True, annot=True)

# %% [markdown]
# ## What is the first thing that you need to do?

# %%
### Add codes here

# %% [markdown]
# # Now, apply LDA/QDA/Logistic Regression to Breast Cancer dataset.

# %%
# play here

# %% [markdown]
# # Did you partition your data for test?
#
# If not, now split data into training and testing.
# Then, check the training and testing erros!

# %%
# play here

# %% [markdown]
# # Are you done already?
#
# - Please help others before we start to discuss next topic.
