# %% [markdown]
# # Assignment #1 - Linear Regression
#
# <font color="red"> <b> Due: Feb 12 (Monday) 11:00 pm </b> </font>

# %% [markdown]
# # <font color="blue"> KIRAN KOREY </font>

# %% [markdown]
# # Introduction
#
# Describe the objective of this assignment. You can briefly state how you accompilsh it.
#
# The objective of this assignment is to implement <b>train()</b> and <b>use()</b> methods of <b>Linear Model </b> - <i><b>Least Squares </b></i>and <i> <b> Least Mean Squares</b></i> and apply these on the choosen data set.
#
# In this assignment I will be Implementing Linear model - Least Squares and Least Mean Squares. To be specific I will implement LinearRegress and LMS class which have Linear Model as its Super Class and Which in turn has Base Model as the super class.
# LinearRegress and LMS both have train() and use() methods which will be used to predict values of the choosen data set.
#
# <font color="brown">** The corectness of the implementation is checked by preliminary tests.</font>
#
# I will use these implemented methods on the housing data that I will introduce in the next section to predict the price of the houce on the basis of living sqft and compare both the Linear model.

# %% [markdown]
# # Data
#
# Introduce your data and visualize them. Describe your observations about the data.
# You can reuse the data that you examined in Assignment #0.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# Reading data 
df = pd.read_csv("home_data.csv",header=0);
df.head()
# Out:
#            id             date   price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900         3       1.00         1180
# 1  6414100192  20141209T000000  538000         3       2.25         2570
# 2  5631500400  20150225T000000  180000         2       1.00          770
# 3  2487200875  20141209T000000  604000         4       3.00         1960
# 4  1954400510  20150218T000000  510000         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
df=df.drop(['id','date'],axis=1)
df.head()
# Out:
#     price  bedrooms  bathrooms  sqft_living  sqft_lot  floors  waterfront  \
# 0  221900         3       1.00         1180      5650     1.0           0
# 1  538000         3       2.25         2570      7242     2.0           0
# 2  180000         2       1.00          770     10000     1.0           0
# 3  604000         4       3.00         1960      5000     1.0           0
# 4  510000         3       2.00         1680      8080     1.0           0
#
#    view  condition  grade  sqft_above  sqft_basement  yr_built  yr_renovated  \
# 0     0          3      7        1180              0      1955             0
# 1     0          3      7        2170            400      1951          1991
# 2     0          3      6         770              0      1933             0
# 3     0          5      7        1050            910      1965             0
# 4     0          3      8        1680              0      1987             0
#
#    zipcode      lat     long  sqft_living15  sqft_lot15
# ...

# %%
# Check for any cell with null values
np.any(df.isnull())
# Out:
# False

# %%
# msrp = np.array(df.loc[:, 'MSRP'])
# msrp
price = np.array(df.loc[:, 'price'])
price
# Out:
# array([221900, 538000, 180000, ..., 402101, 400000, 325000], dtype=int64)

# %%
# To check the average of the prices
np.average(price)
# Out:
# 540088.14190533478

# %%
# To plot a graph of all the attributes to find out the trend of each attribute
fig = plt.figure(figsize=(16,12))
plt.clf()
for i in range(19):
    plt.subplot(5, 5, i+1)
    plt.plot(df.iloc[:, i])
    plt.ylabel(df.columns.values[i])
fig.tight_layout()

# %%
# To plot a grap of all the attributes with rrespect to Price attribute

fig = plt.figure(figsize=(16,12))
plt.clf()
for i in range(19):
    plt.subplot(5, 5, i+1)
    plt.plot(price,df.iloc[:, i], '.')
    plt.xlabel(df.columns.values[i])
    plt.ylabel('price')
fig.tight_layout()

# %% [markdown]
# # Method
#
# Summarize the linear models (least-squares and LMS) and explain your implementation of **class** *LinearModel*.
# The explanation of your codes should not be the comments in a code cell.
# This section should include
#  - review of the linear models
#  - your implementation and description

# %% [markdown]
# ### Super Classs Definition

# %%
import numpy as np 
from abc import ABC, abstractmethod

# Super class for machine learning models 

class BaseModel(ABC):
    """ Super class for ITCS Machine Learning Class"""
    
    @abstractmethod
    def train(self, X, T):
        pass

    @abstractmethod
    def use(self, X):
        pass

    
class LinearModel(BaseModel):
    """
        Abstract class for a linear model 
        
        Attributes
        ==========
        w       ndarray
                weight vector/matrix
    """

    def __init__(self):
        """
            weight vector w is initialized as None
        """
        self.w = None

    def _check_matrix(self, mat, name):
        if len(mat.shape) != 2:
            raise ValueError(''.join(["Wrong matrix ", name]))
        
    # add a basis
    def add_ones(self, X):
        """
            add a column basis to X input matrix
        """
        self._check_matrix(X, 'X')
        return np.hstack((np.ones((X.shape[0], 1)), X))

    ####################################################
    #### abstract funcitons ############################
    @abstractmethod
    def train(self, X, T):
        """
            train linear model
            
            parameters
            -----------
            X     2d array
                  input data
            T     2d array
                  target labels
        """        
        pass
    
    @abstractmethod
    def use(self, X):
        """
            apply the learned model to input X
            
            parameters
            ----------
            X     2d array
                  input data
            
        """        
        pass

# %% [markdown]
# ### Least Squares

# %%
# Linear Regression Class for least squares
class LinearRegress(LinearModel): 
    """ 
        LinearRegress class 
        
        attributes
        ===========
        w    nd.array  (column vector/matrix)
             weights
    """
    def __init__(self):
        LinearModel.__init__(self)
        
    # train lease-squares model
    def train(self, X, T):
        X1 = self.add_ones(X)
        self.w = np.linalg.solve(X1.T @ X1, X1.T @ T)
#         pass  ## TODO: replace this with your codes
    
    # apply the learned model to data X
    def use(self, X):
        X1 = self.add_ones(X)
        return X1 @ self.w
        #pass  ## TODO: replace this with your codes

# %% [markdown]
# ### Least Mean Squares

# %%
import collections # for checking iterable instance

# LMS class 
class LMS(LinearModel):
    """
        Lease Mean Squares. online learning algorithm
    
        attributes
        ==========
        w        nd.array
                 weight matrix
        alpha    float
                 learning rate
    """
    def __init__(self, alpha):
        LinearModel.__init__(self)
        self.alpha = alpha
        
    def train_step(self, x, t):
        x.shape=(1,x.shape[0]); #1,3
        x1 = self.add_ones(x)
        if(self.w is None):
            self.w=np.zeros((1,x1.shape[1])) # initialized w to zeros(1,3) 
        y = np.inner(self.w , x1)
        self.w =self.w - self.alpha * (y - t) * x1
    
    # batch training by using train_step function
    def train(self, X, T):
        for x, t in zip(X, T):
            self.train_step(x, t)
            
    
    # apply the current model to data X
    def use(self, X):
        X1 = self.add_ones(X)
        return X1 @ self.w.T

# %% [markdown]
# ### Usage Examples

# %%
# HERE follow are for my code tests.

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
X = np.linspace(0,10, 11).reshape((-1, 1))
T = -2 * X + 3.2
print(T)
ls = LinearRegress()

ls.train(X, T)

plt.plot(ls.use(X))
# Out:
# [[  3.2]
#  [  1.2]
#  [ -0.8]
#  [ -2.8]
#  [ -4.8]
#  [ -6.8]
#  [ -8.8]
#  [-10.8]
#  [-12.8]
#  [-14.8]
#  [-16.8]]

# %%
lms = LMS(0.1)
for x, t in zip(X, T):
    lms.train_step(x, t)
    plt.plot(lms.use(X))

# %%
lms.train(X, T)
plt.plot(lms.use(X))

# %% [markdown]
# # Experiments
#
# Apply two methods on the data and discuss the results.
# Please describe your experiment and related codes. You may have subsections of results and discussions here.

# %% [markdown]
# # Conclusions
#
# Discuss the challenges or somethat that you learned.
# If you have any suggestion about the assignment, you can write about it.

# %% [markdown]
# # References

# %% [markdown]
# # Extra Credit
#
# If you want to work more for an extra credit, place your work here about weight analysis.
# Try to answer to the question:
# - what is the most and least significant features for your data.
# - what are the consequences if you remove those features from the model?

# %% [markdown]
# ## Grading
#
# DO NOT forget to submit your data! Your notebook is supposed to run well after running your codes.
#
# Points | | Description
# --|--|:--
# 5 | Introduction
# 20 | Data |
#  | 5| description
#  | 5| plots for understanding or analysis
#  | 5| preliminary observation
#  | 5| Preprocessing of the data
# 40 | Method |
#  | 5| review
#  | 5| explanation of codes
#  | 30| Correct implementation (preliminary test)
# 30 | Experiments |
#  | 5| description, codes
#  | 10| visualization of results
#  | 15| analysis / comparison of algorithms
# 5 | Conclusions, References

# %% [markdown]
# # Preliminary Test

# %%
##################### WHAT I WILL RELEASE ############

# Self-Test code for accuracy of your model - DO NOT MODIFY THIS
# Primilnary test data
X = np.array([[2,5],
              [6,2],
              [1,9],
              [4,5],
              [6,3],
              [7,4],
              [8,3]])
T = X[:,0, None] * 3 - 2 * X[:, 1, None] + 3
N = X.shape[0]

def rmse(T, Y):
    return np.sqrt(np.sum((T-Y)**2))

model_names = ['LS', 'LMS_All', 'LMS_1STEP']
models = [LinearRegress(), LMS(0.02), LMS(0.02)]
#train
for i, model in enumerate(models):
    print("training ", model_names[i], "...") 
    if i == len(models) -1: 
        # train only one step for LMS2
        model.train_step(X[0], T[0])
    else:
        model.train(X, T)

def check(a, b, eps=np.finfo(float).eps):
    if abs(a-b) > eps:
        print("failed.", a, b)
    else:
        print("passed.")

errors = [1.19e-13, 2.8753214702, 38.0584918251]
for i, model in enumerate(models):
    print("---- Testing ", model_names[i], "...", end=" ") 

    # rmse test
    err = rmse(T, model.use(X))
    if check(err, errors[i], eps=1e-10):
        print ("check your weights: ", model.w)
        print ("oracle: ", )
# Out:
# training  LS ...
# training  LMS_All ...
# training  LMS_1STEP ...
# ---- Testing  LS ... passed.
# ---- Testing  LMS_All ... passed.
# ---- Testing  LMS_1STEP ... passed.
